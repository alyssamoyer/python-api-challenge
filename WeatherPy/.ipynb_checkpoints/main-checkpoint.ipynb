# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from apikey import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Generate Cities List

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
numofcities = len(cities)

# %%
#Creating a df to collect the API results in
cities_df = pd.DataFrame()
cities_df["City"] = ""
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = ""
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Wind Speed"] = ""

# %%
#Perform API Calls

base_url = "http://api.openweathermap.org/data/2.5/weather?"

params = {
    "APPID" :api_key,
     "units": "imperial"
}

cities_count = 0

#The API call has a limit of 60 calls a minute, create a list from 0 to the number of cities that steps by 60 
steps = np.arange(1, numofcities, 0.5).tolist()



for city in cities:
    
    #setting the q parameter to the current city name for the API call
    params["q"] = city
    
    #keeping track of the index
    cities_count = cities_count + 1
    
    #Make API call and print out city name and number
    print(f"Processing Record {cities_count}|{city}.")
    response = requests.get(base_url, params=params).json()
    
    #Adding API response into the cities DataFrame
    try:
        
        cities_df.loc[cities_count, 'City'] = response['name']
        cities_df.loc[cities_count, 'Cloudiness'] = response['clouds']['all']
        cities_df.loc[cities_count, 'Country'] = response['sys']["country"]
        cities_df.loc[cities_count, 'Date'] = response['dt']
        cities_df.loc[cities_count, 'Humidity'] = response['main']['humidity']
        cities_df.loc[cities_count, 'Lat'] = response['coord']['lat']
        cities_df.loc[cities_count, 'Lng'] = response['coord']['lon']
        cities_df.loc[cities_count, 'Max Temp'] = response['main']['temp_max']
        cities_df.loc[cities_count, 'Wind Speed'] = response['wind']['speed']
    
    except TimeoutError:
        print("City not found... skipping.")
    except (KeyError, IndexError):
        print("City not found... skipping.")
    time.sleep(steps[cities_count])
# Out:
# Processing Record 1|nikolskoye.
# Processing Record 2|ravar.
# Processing Record 3|punta arenas.
# Processing Record 4|capinota.
# Processing Record 5|rikitea.
# Processing Record 6|cayenne.
# Processing Record 7|tumannyy.
# City not found... skipping.
# Processing Record 8|tsihombe.
# City not found... skipping.
# Processing Record 9|victoria.
# Processing Record 10|vila velha.
# Processing Record 11|charters towers.
# Processing Record 12|kayerkan.
# Processing Record 13|provideniya.
# Processing Record 14|sao filipe.
# Processing Record 15|ushuaia.
# Processing Record 16|lagoa.
# Processing Record 17|port alfred.
# Processing Record 18|mar del plata.
# Processing Record 19|san andres.
# Processing Record 20|naze.
# Processing Record 21|amderma.
# City not found... skipping.
# Processing Record 22|lianzhou.
# Processing Record 23|zhaotong.
# Processing Record 24|illoqqortoormiut.
# City not found... skipping.
# Processing Record 25|touros.
# Processing Record 26|albany.
# Processing Record 27|hobart.
# Processing Record 28|cherskiy.
# Processing Record 29|henties bay.
# Processing Record 30|atuona.
# Processing Record 31|georgetown.
# Processing Record 32|makakilo city.
# Processing Record 33|bambous virieux.
# Processing Record 34|taolanaro.
# City not found... skipping.
# Processing Record 35|la palma.
# Processing Record 36|priiskovyy.
# Processing Record 37|murray bridge.
# Processing Record 38|bethel.
# Processing Record 39|shahr-e babak.
# Processing Record 40|hami.
# Processing Record 41|avarua.
# Processing Record 42|vaini.
# Processing Record 43|tiksi.
# Processing Record 44|llangefni.
# Processing Record 45|mataura.
# Processing Record 46|kapaa.
# Processing Record 47|chojnice.
# Processing Record 48|belushya guba.
# City not found... skipping.
# Processing Record 49|aklavik.
# Processing Record 50|sentyabrskiy.
# City not found... skipping.
# Processing Record 51|saint anthony.
# Processing Record 52|ostrovnoy.
# Processing Record 53|mogadishu.
# Processing Record 54|filingue.
# Processing Record 55|hithadhoo.
# Processing Record 56|yellowknife.
# Processing Record 57|barentsburg.
# City not found... skipping.
# Processing Record 58|fortuna.
# Processing Record 59|yining.
# Processing Record 60|bluff.
# Processing Record 61|kaitangata.
# Processing Record 62|hirado.
# Processing Record 63|puerto escondido.
# Processing Record 64|chinhoyi.
# Processing Record 65|san patricio.
# Processing Record 66|ondjiva.
# Processing Record 67|kruisfontein.
# Processing Record 68|castro.
# Processing Record 69|maneadero.
# City not found... skipping.
# Processing Record 70|kysyl-syr.
# Processing Record 71|saint-philippe.
# Processing Record 72|hilo.
# Processing Record 73|salalah.
# Processing Record 74|khandyga.
# Processing Record 75|longyearbyen.
# Processing Record 76|key west.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-8ac41dc47b43> in <module>
#      44     except (KeyError, IndexError):
#      45         print("City not found... skipping.")
# ---> 46     time.sleep(steps[cities_count])
#      47
#
# KeyboardInterrupt:

# %%
#Perform API Calls

base_url = "http://api.openweathermap.org/data/2.5/weather?"

params = {
    "APPID" :api_key,
     "units": "imperial"
}

cities_count = 0

x = 0
time_steps = np.arange(1, numofcities, 0.5).tolist()
time_track = 0
#The API call has a limit of 60 calls a minute, create a list from 0 to the number of cities that steps by 60 
steps = np.arange(0, numofcities, 40).tolist()
steps.append(numofcities-1)

for step in steps:

    while cities_count < steps[x]:
    
        #setting the q parameter to the current city name for the API call
        params["q"] = cities[cities_count]
    
        #keeping track of the index
        cities_count = cities_count + 1
        
        #Make API call and print out city name and number
        print(f"Processing Record {cities_count}|{cities[cities_count]}.")
        response = requests.get(base_url, params=params).json()

        #Adding API response into the cities DataFrame
        try:

            cities_df.loc[cities_count, 'City'] = response['name']
            cities_df.loc[cities_count, 'Cloudiness'] = response['clouds']['all']
            cities_df.loc[cities_count, 'Country'] = response['sys']["country"]
            cities_df.loc[cities_count, 'Date'] = response['dt']
            cities_df.loc[cities_count, 'Humidity'] = response['main']['humidity']
            cities_df.loc[cities_count, 'Lat'] = response['coord']['lat']
            cities_df.loc[cities_count, 'Lng'] = response['coord']['lon']
            cities_df.loc[cities_count, 'Max Temp'] = response['main']['temp_max']
            cities_df.loc[cities_count, 'Wind Speed'] = response['wind']['speed']

        except TimeoutError:
            print("City not found... skipping.")
        except (KeyError, IndexError):
            print("City not found... skipping.")
        time.sleep(time_steps[time_track])
        time_track = time_track + 1
    x = x + 1
    time_track = 0
# Out:
# Processing Record 1|punta arenas.
# Processing Record 2|ushuaia.
# Processing Record 3|new norfolk.
# Processing Record 4|hermanus.
# Processing Record 5|ucluelet.
# Processing Record 6|ituni.
# Processing Record 7|mar del plata.
# City not found... skipping.
# Processing Record 8|lebu.
# Processing Record 9|busselton.
# Processing Record 10|lagoa.
# Processing Record 11|ribeira grande.
# Processing Record 12|faanui.
# Processing Record 13|half moon bay.
# Processing Record 14|ajaccio.
# Processing Record 15|thinadhoo.
# Processing Record 16|albany.
# Processing Record 17|merauke.
# Processing Record 18|kashi.
# Processing Record 19|samusu.
# City not found... skipping.
# Processing Record 20|vaini.
# City not found... skipping.
# Processing Record 21|tiarei.
# Processing Record 22|yulara.
# Processing Record 23|dikson.
# Processing Record 24|ponta do sol.
# Processing Record 25|port shepstone.
# Processing Record 26|hobart.
# Processing Record 27|bati.
# Processing Record 28|bathsheba.
# Processing Record 29|atuona.
# Processing Record 30|hilo.
# Processing Record 31|sicamous.
# Processing Record 32|emba.
# Processing Record 33|saint-joseph.
# Processing Record 34|borovikha.
# Processing Record 35|port hedland.
# Processing Record 36|biak.
# Processing Record 37|torbay.
# Processing Record 38|severo-kurilsk.
# Processing Record 39|ketchikan.
# Processing Record 40|port alfred.
# Processing Record 41|mys shmidta.
# Processing Record 42|nikolskoye.
# City not found... skipping.
# Processing Record 43|barrow.
# Processing Record 44|tiksi.
# Processing Record 45|tabas.
# Processing Record 46|westerland.
# Processing Record 47|pacifica.
# Processing Record 48|qaanaaq.
# Processing Record 49|saldanha.
# Processing Record 50|tadine.
# Processing Record 51|kavaratti.
# Processing Record 52|kamenskoye.
# Processing Record 53|marawi.
# City not found... skipping.
# Processing Record 54|chuy.
# Processing Record 55|ancud.
# Processing Record 56|kavieng.
# Processing Record 57|rikitea.
# Processing Record 58|sapa.
# Processing Record 59|taolanaro.
# Processing Record 60|union.
# City not found... skipping.
# Processing Record 61|antofagasta.
# Processing Record 62|illoqqortoormiut.
# Processing Record 63|bethel.
# City not found... skipping.
# Processing Record 64|louisbourg.
# Processing Record 65|ilawa.
# City not found... skipping.
# Processing Record 66|yenagoa.
# City not found... skipping.
# Processing Record 67|gimli.
# Processing Record 68|airai.
# Processing Record 69|attawapiskat.
# Processing Record 70|sao joao da barra.
# City not found... skipping.
# Processing Record 71|husavik.
# Processing Record 72|tanete.
# Processing Record 73|hovd.
# Processing Record 74|sistranda.
# Processing Record 75|leshan.
# Processing Record 76|georgetown.
# Processing Record 77|sedalia.
# Processing Record 78|banda aceh.
# Processing Record 79|deoband.
# Processing Record 80|laguna.
# Processing Record 81|ixtapa.
# Processing Record 82|barentsburg.
# Processing Record 83|ghoti.
# City not found... skipping.
# Processing Record 84|nasriganj.
# Processing Record 85|marystown.
# Processing Record 86|inirida.
# Processing Record 87|puerto ayora.
# Processing Record 88|cidreira.
# Processing Record 89|mataura.
# Processing Record 90|hasaki.
# Processing Record 91|jamestown.
# Processing Record 92|dehloran.
# Processing Record 93|marcona.
# Processing Record 94|pisco.
# City not found... skipping.
# Processing Record 95|wajir.
# Processing Record 96|codrington.
# Processing Record 97|kaitangata.
# Processing Record 98|nizhneyansk.
# Processing Record 99|umzimvubu.
# City not found... skipping.
# Processing Record 100|coahuayana.
# City not found... skipping.
# Processing Record 101|nkhotakota.
# Processing Record 102|vanimo.
# Processing Record 103|kahului.
# Processing Record 104|talnakh.
# Processing Record 105|butaritari.
# Processing Record 106|beloha.
# Processing Record 107|okha.
# Processing Record 108|xichang.
# Processing Record 109|saskylakh.
# Processing Record 110|arraial do cabo.
# Processing Record 111|provideniya.
# Processing Record 112|scarborough.
# Processing Record 113|castro.
# Processing Record 114|salaga.
# Processing Record 115|la ronge.
# Processing Record 116|eureka.
# Processing Record 117|dunedin.
# Processing Record 118|korla.
# Processing Record 119|fairbanks.
# City not found... skipping.
# Processing Record 120|mao.
# Processing Record 121|kenai.
# Processing Record 122|kutum.
# Processing Record 123|casas grandes.
# Processing Record 124|kapaa.
# Processing Record 125|meyungs.
# Processing Record 126|upernavik.
# City not found... skipping.
# Processing Record 127|port blair.
# Processing Record 128|kimbe.
# Processing Record 129|cape town.
# Processing Record 130|bardiyah.
# Processing Record 131|dhidhdhoo.
# City not found... skipping.
# Processing Record 132|tuktoyaktuk.
# Processing Record 133|praia.
# Processing Record 134|ayer itam.
# Processing Record 135|bumba.
# City not found... skipping.
# Processing Record 136|masallatah.
# Processing Record 137|pevek.
# Processing Record 138|novorudnyy.
# Processing Record 139|tasiilaq.
# Processing Record 140|san patricio.
# Processing Record 141|thompson.
# Processing Record 142|valparaiso.
# Processing Record 143|khatanga.
# Processing Record 144|fortuna.
# Processing Record 145|salalah.
# Processing Record 146|shchelyayur.
# Processing Record 147|iqaluit.
# City not found... skipping.
# Processing Record 148|bluff.
# Processing Record 149|saint-louis.
# Processing Record 150|grinnell.
# Processing Record 151|litoral del san juan.
# Processing Record 152|mimoso do sul.
# City not found... skipping.
# Processing Record 153|sur.
# Processing Record 154|ostrovnoy.
# Processing Record 155|kysyl-syr.
# Processing Record 156|grand river south east.
# Processing Record 157|meulaboh.
# City not found... skipping.
# Processing Record 158|port elizabeth.
# Processing Record 159|tocache.
# Processing Record 160|zverinogolovskoye.
# Processing Record 161|warangal.
# Processing Record 162|bengkulu.
# Processing Record 163|nanortalik.
# City not found... skipping.
# Processing Record 164|mahebourg.
# Processing Record 165|cayenne.
# Processing Record 166|longyearbyen.
# Processing Record 167|nha trang.
# Processing Record 168|east london.
# Processing Record 169|katherine.
# Processing Record 170|anloga.
# Processing Record 171|narkevychi.
# Processing Record 172|jumla.
# Processing Record 173|aanekoski.
# Processing Record 174|yellowknife.
# Processing Record 175|la asuncion.
# Processing Record 176|aykhal.
# Processing Record 177|amderma.
# Processing Record 178|myingyan.
# City not found... skipping.
# Processing Record 179|warri.
# Processing Record 180|vao.
# Processing Record 181|tulum.
# Processing Record 182|xuanhua.
# Processing Record 183|ouadda.
# Processing Record 184|williston.
# Processing Record 185|kodiak.
# Processing Record 186|vardo.
# Processing Record 187|loikaw.
# Processing Record 188|saint george.
# Processing Record 189|sambava.
# Processing Record 190|katsuura.
# Processing Record 191|smiths falls.
# Processing Record 192|ruatoria.
# Processing Record 193|leningradskiy.
# City not found... skipping.
# Processing Record 194|cabo san lucas.
# Processing Record 195|boa vista.
# Processing Record 196|vila.
# Processing Record 197|hambantota.
# Processing Record 198|jalu.
# Processing Record 199|kelvington.
# Processing Record 200|basoko.
# Processing Record 201|amethi.
# Processing Record 202|nuevitas.
# Processing Record 203|beringovskiy.
# Processing Record 204|mabaruma.
# Processing Record 205|sitka.
# Processing Record 206|karratha.
# Processing Record 207|aguie.
# Processing Record 208|tiangua.
# Processing Record 209|fort-shevchenko.
# Processing Record 210|hauterive.
# Processing Record 211|xining.
# Processing Record 212|tokuyama.
# Processing Record 213|aklavik.
# Processing Record 214|atar.
# Processing Record 215|luyang.
# Processing Record 216|avarua.
# Processing Record 217|tefe.
# Processing Record 218|berlevag.
# Processing Record 219|san felipe.
# Processing Record 220|isangel.
# Processing Record 221|bani walid.
# Processing Record 222|frontignan.
# Processing Record 223|lavrentiya.
# Processing Record 224|nome.
# Processing Record 225|bredasdorp.
# Processing Record 226|anuradhapura.
# Processing Record 227|csanadapaca.
# Processing Record 228|angoram.
# Processing Record 229|saleaula.
# Processing Record 230|reconquista.
# City not found... skipping.
# Processing Record 231|taoudenni.
# Processing Record 232|shahpura.
# Processing Record 233|chiredzi.
# Processing Record 234|sumbawanga.
# Processing Record 235|carnarvon.
# Processing Record 236|alvaraes.
# Processing Record 237|panama city.
# Processing Record 238|hithadhoo.
# Processing Record 239|shimoda.
# Processing Record 240|tsihombe.
# Processing Record 241|saint-philippe.
# City not found... skipping.
# Processing Record 242|flinders.
# Processing Record 243|norman wells.
# Processing Record 244|roma.
# Processing Record 245|pacific grove.
# Processing Record 246|bolungarvik.
# Processing Record 247|mount gambier.
# City not found... skipping.
# Processing Record 248|ajdabiya.
# Processing Record 249|armacao dos buzios.
# Processing Record 250|raudeberg.
# City not found... skipping.
# Processing Record 251|kabinda.
# Processing Record 252|hinton.
# Processing Record 253|neuquen.
# Processing Record 254|westport.
# Processing Record 255|kruisfontein.
# Processing Record 256|doha.
# Processing Record 257|almunecar.
# Processing Record 258|rorvik.
# Processing Record 259|kasrawad.
# Processing Record 260|nouadhibou.
# Processing Record 261|utiroa.
# Processing Record 262|andros town.
# City not found... skipping.
# Processing Record 263|kuche.
# Processing Record 264|sola.
# City not found... skipping.
# Processing Record 265|taltal.
# Processing Record 266|san lazaro.
# Processing Record 267|opuwo.
# Processing Record 268|beyneu.
# Processing Record 269|havoysund.
# Processing Record 270|sorland.
# Processing Record 271|didsbury.
# Processing Record 272|dagshai.
# Processing Record 273|esperance.
# Processing Record 274|anito.
# Processing Record 275|yuzhno-kurilsk.
# Processing Record 276|sabang.
# Processing Record 277|tumannyy.
# Processing Record 278|vila franca do campo.
# City not found... skipping.
# Processing Record 279|castro-urdiales.
# Processing Record 280|abong mbang.
# Processing Record 281|hamilton.
# Processing Record 282|den helder.
# Processing Record 283|setermoen.
# Processing Record 284|smithers.
# Processing Record 285|karaton.
# Processing Record 286|ilulissat.
# Processing Record 287|santa barbara.
# Processing Record 288|san cristobal.
# Processing Record 289|pangnirtung.
# Processing Record 290|agva.
# Processing Record 291|uusikaupunki.
# City not found... skipping.
# Processing Record 292|lata.
# Processing Record 293|santa eulalia del rio.
# Processing Record 294|mayumba.
# City not found... skipping.
# Processing Record 295|saint anthony.
# Processing Record 296|azare.
# Processing Record 297|kangaatsiaq.
# Processing Record 298|caravelas.
# Processing Record 299|palana.
# Processing Record 300|belushya guba.
# Processing Record 301|saint-georges.
# City not found... skipping.
# Processing Record 302|kempsey.
# Processing Record 303|huarmey.
# Processing Record 304|hvammstangi.
# Processing Record 305|puerto escondido.
# City not found... skipping.
# Processing Record 306|lebedyn.
# Processing Record 307|sorong.
# Processing Record 308|lishui.
# Processing Record 309|magadan.
# Processing Record 310|fevralsk.
# Processing Record 311|lincoln.
# City not found... skipping.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-4c08526459f7> in <module>
#      47         except (KeyError, IndexError):
#      48             print("City not found... skipping.")
# ---> 49         time.sleep(time_steps[time_track])
#      50         time_track = time_track + 1
#      51     x = x + 1
#
# KeyboardInterrupt:

# %%
#Export dataframe to csv
cities_df.to_csv(output_data_file)

#Display the dataframe
cities_df
# Out:
#                  City  Cloudiness Country        Date  Humidity    Lat  \
# 1              Touros           0      BR  1578381441        94  -5.20
# 2        Punta Arenas           0      CL  1578381442        81 -53.16
# 3             Ushuaia           0      AR  1578381303        62 -54.81
# 4         New Norfolk           0      AU  1578381446        63 -42.78
# 5            Hermanus           0      ZA  1578381448        75 -34.42
# ..                ...         ...     ...         ...       ...    ...
# 306  Puerto Escondido           0      MX  1578384705        51  15.86
# 307           Lebedyn           0      UA  1578384719        78  50.58
# 308            Sorong           0      ID  1578384733        97  -0.86
# 309            Lishui           0      CN  1578384748        74  28.45
# 310           Magadan           0      RU  1578384763        72  59.56
#
#         Lng  Max Temp  Wind Speed
# 1    -35.46     75.20        4.70
# 2    -70.91     51.80        8.05
# 3    -68.31     55.40       18.34
# 4    147.06     68.00       13.87
# 5     19.24     71.01       11.99
# ..      ...       ...         ...
# 306  -97.07     69.21        5.39
# 307   34.48     25.52        4.29
# 308  131.25     76.21        2.98
# 309  119.91     60.22        3.56
# 310  150.80      2.43        9.64
#
# [275 rows x 9 columns]

# %%
#Plotting the Data

#Latitude vs. Temperature Plot

#Create a new df with lat and max temp as the type integers
lat_maxtemp = cities_df[["Lat", "Max Temp"]].astype(int)

#Plot a scatterplot with x as latitute and y as max temperature
lat_maxtemp_plot = lat_maxtemp.plot(kind="scatter", x = "Lat", y = "Max Temp", s=26, edgecolors='black')

#Adding chart title, axis labels, and grid lines
plt.title("City Latitude vs Max Temperature (1/1/2020)")

lat_maxtemp_plot.set_xlabel("Latitude")
lat_maxtemp_plot.set_ylabel("Max Temperature (F)")  

lat_maxtemp_plot.grid()

plt.savefig("maxtemp.png")
plt.show()
plt.tight_layout()

# %%
#Plotting the Data

#Latitude vs. Humidity Plot

#Create a new df with lat and humidity as the type integers
lat_humidity = cities_df[["Lat", "Humidity"]].astype(int)

#Plot a scatterplot with x as latitute and y as humidity
lat_hum_plot = lat_humidity.plot(kind="scatter", x = "Lat", y = "Humidity", s=26, edgecolors='black')

#Adding chart title, axis labels, and grid lines
plt.title("City Latitude vs Humidity (1/1/2020)")

lat_hum_plot.set_xlabel("Latitude")
lat_hum_plot.set_ylabel("Humidity (%)")  

lat_hum_plot.grid()

plt.savefig("humidity.png")
plt.show()
plt.tight_layout()

# %%
#Plotting the Data

#Latitude vs. Cloudiness Plot

#Create a new df with lat and cloudiness as the type integers
lat_cloud = cities_df[["Lat", "Cloudiness"]].astype(int)

#Plot a scatterplot with x as latitute and y as cloudiness
lat_cloud_plot = lat_cloud.plot(kind="scatter", x = "Lat", y = "Cloudiness", s=26, edgecolors='black')

#Adding chart title, axis labels, and grid lines
plt.title("City Latitude vs Cloudiness (1/1/2020)")

lat_cloud_plot.set_xlabel("Latitude")
lat_cloud_plot.set_ylabel("Cloudiness (%)")  

lat_cloud_plot.grid()

plt.savefig("cloudiness.png")
plt.show()
plt.tight_layout()

# %%
#Plotting the Data

#Latitude vs. Wind Speed Plot

#Create a new df with lat and humidity as the type integers
lat_wind = cities_df[["Lat", "Wind Speed"]].astype(int)

#Plot a scatterplot with x as latitute and y as humidity
lat_wind_plot = lat_wind.plot(kind="scatter", x = "Lat", y = "Wind Speed", s=26, edgecolors='black')

#Adding chart title, axis labels, and grid lines
plt.title("City Latitude vs Wind Speed (1/1/2020)")

lat_wind_plot.set_xlabel("Latitude")
lat_wind_plot.set_ylabel("Wind Speed (mph)")  

lat_wind_plot.grid()

plt.savefig("wind.png")
plt.show()
plt.tight_layout()
